# %% [markdown]
# # Overview
#  - How to install and use Jupyter Notebook
#  - Steps : Install Anaconda >> Execute Jupyter Notebook >> .ipynb Usage

# %% [markdown]
# ## [Step.1] Install Anaconda / 아나콘다 설치

# %% [markdown]
# ### What is Anaconda?
#  - 수학, 과학 분야에서 사용되는 여러 패키지들을 묶어 놓은 파이썬 배포판
#  - 데이터사이언스 등과 관련한 패키지와 개발환경을 포함하고 있는 소프트웨어의 배포판
#  - A distribution of the Python and R programming languages for scientific computing.
#  - Scientific computing includes...
#    - data science
#    - maching learning application
#    - large-scale data processing
#    - predictive analytics
#    - (and so on)

# %% [markdown]
# ### 설치
#  - 1) https://www.anaconda.com
#  - 2)  <a href='https://www.anaconda.com'> Anaconda 공식 홈페이지</a> 에서 Individual Edition(open source)를 개인 환경에 맞는 버전으로 다운로드받고 실행한다. (캡처들)

# %%
from IPython.display import Image
Image("../Lectures_data/anaconda_01.png")

# %%
Image("../Lectures_data/anaconda_02.png")

# %% [markdown]
# ## [Step.2] Execute Jupyter Notebook / Jupyter Notebook 실행
# ### 실행
#  - 1) 'Anaconda-Navigator'를 실행
#  - 2) 'Jupyter Notebook'을 Launch (캡처)
#  - 3) Notebook 오른쪽 상단의 'New' >> 'python 3' >> noetbook 실행
#  - (참고) Jupyter Notebook을 실행했을 때 나오는 Directory는 바탕화면(Desktop) 직전의 Directory 이다.

# %%
Image("../Lectures_data/anaconda_03.png")

# %%
Image("../Lectures_data/anaconda_04.png")

# %%
Image("../Lectures_data/anaconda_05.png")

# %% [markdown]
# #### 참고해볼 만한 Reference
#  - https://blog.naver.com/PostView.nhn?blogId=hobbang143&logNo=221464304548
